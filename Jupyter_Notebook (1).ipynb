# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Eva Pettemeridou** <br>
# Post-doctoral Fellow

# %% [markdown]
# *I am interested in data science because I want to develop a multisensory system that will classify emotions.*

# %% [markdown]
# ### This code will give the result of 1+1 and will print the result in words.

# %%
1+1
print("Two")
# Out:
# Two

# %% [markdown]
# - This is a bullet
#
# ![2022-05-13.png](attachment:3d6a639e-907b-4b59-8d57-4a7c86e79e89.png)
#
# [Click here to Google](https://www.google.com/)
